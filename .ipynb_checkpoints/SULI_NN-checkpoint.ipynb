# %%
from tqdm import tqdm
from time import time
from tqdm import trange

import matplotlib.pyplot as plt
import numpy as np
import scipy

import jax
import jax.flatten_util as flatten_util
import jax.numpy as jnp

from flax import linen as nn

from typing import NamedTuple

# %%
seed = 42

# %%
class SpringState(NamedTuple):
    phi: jnp.ndarray
    buffer: jnp.ndarray
    buffer_index: jnp.ndarray
    r_hat: float
    beta: float
    checkpoint_idx: int

# %%
class SpringCleanState(NamedTuple):
    phi: jnp.ndarray

# %%
class ResNet(nn.Module):
    """A simple ResNet model."""

    @nn.compact
    def __call__(self, x):
        x = nn.Dense(features=50)(jnp.sin(2 * jnp.pi * x))
        x = nn.tanh(x)

        y = nn.Dense(features=50)(x)
        x = x + nn.tanh(y)

        y = nn.Dense(features=50)(x)
        x = x + nn.tanh(y)

        y = nn.Dense(features=50)(x)
        x = x + nn.tanh(y)

        x = nn.Dense(features=1)(x)
        return x


model_fn = ResNet()

# %%
def scalar_model_fn(params, batch):
    return model_fn.apply(params, batch)[0]


model_grad = jax.value_and_grad(scalar_model_fn, argnums=0)


def raveled_grad_fn(params, batch):
    value, grad = model_grad(params, batch)
    return value, flatten_util.ravel_pytree(grad)[0]


jacobian_fn = jax.jit(jax.vmap(raveled_grad_fn, in_axes=(None, 0), out_axes=(0, 0)))

# %%
key = jax.random.PRNGKey(seed)
ord = 15 #Change to make more ill conditioned

coeff = jax.random.normal(key, shape=(ord,))
poly = np.polynomial.chebyshev.Chebyshev(coeff)

def target_fn(x):
    return poly(jnp.sin(2 * jnp.pi * x)) / np.sqrt(ord)

# %%
plt.rcParams.update({'font.size': 14})
plt.rcParams.update({'axes.labelsize': 14})

xs = np.linspace(0,1,500)
plt.plot(xs, target_fn(xs))
plt.xlabel("s")
plt.ylabel("f(s)")
#plt.savefig("NN_target_fn.pdf", bbox_inches='tight')

# %%
def loss_fn(model_params, xs):
    """Mean-squared error loss"""
    predictions = model_fn.apply(model_params, xs)
    targets = target_fn(xs)

    return jnp.mean((predictions - targets) ** 2)


loss_fn = jax.jit(loss_fn)
loss_fn_grad = jax.jit(jax.value_and_grad(loss_fn, argnums=0))

# %%
rng = jax.random.PRNGKey(seed)

rng, key = jax.random.split(rng)
dummy_x = jax.random.uniform(key, shape=(100, 1))

rng, key = jax.random.split(rng)
params = model_fn.init(key, dummy_x)
param_vec, unravel_fn = flatten_util.ravel_pytree(params)

initial_params = params

print(f"nparams: {jax.flatten_util.ravel_pytree(params)[0].shape[0]}")

# %% [markdown]
# ## Kaczmarz Algorithm (Without adaptive acceleration)

# %%
def get_NGD_optimizer(params, rng, dummy_x, alpha, lamb):
    param_vec, unravel_fn = flatten_util.ravel_pytree(params)
    opt_state = []

    def step(params, batch, targets, opt_state, rng):
        batch_size = batch.shape[0]

        predictions, jacobian = jacobian_fn(params, batch)
        residuals = (targets - predictions)

        loss = jnp.sum(residuals**2) / batch_size

        jacobian /= jnp.sqrt(batch_size)
        residuals /= jnp.sqrt(batch_size)

        T = jacobian @ jacobian.T + lamb * jnp.eye(batch_size)

        ravel_update = jacobian.T @ jax.scipy.linalg.solve(T, residuals, assume_a="pos")

        update = unravel_fn(ravel_update)
        params = jax.tree.map(lambda p, u: p + alpha * u, params, update)

        return params, [], rng, loss, None

    return opt_state, jax.jit(step), rng

# %%
rng = jax.random.PRNGKey(seed)

lamb = 1e-2 #regularization parameter, same as in Kaczmarz
alpha = 0.5 #learning rate, 
num_it = 500

rng, key = jax.random.split(rng)
params = model_fn.init(key, dummy_x)

loss_list = []

opt_state, opt_step, rng  = get_NGD_optimizer(params, rng, dummy_x, alpha, lamb)

batch_size = 500

start_it = 20
mid_thresh = 1e-2
mid_it = None
end_it = 2500

start_params = None
mid_params = None
end_params = None

# Training loop
with trange(num_it, unit="its", position=0, leave=True) as pbar:
    for i in pbar:
        rng, key = jax.random.split(rng)
        batch = jax.random.uniform(key, shape=(batch_size, 1))
        targets = target_fn(batch)[:, 0]

        params, opt_state, rng, loss, aux = opt_step(params, batch, targets, opt_state, rng)

        if i == start_it:
          start_params = params
        if i == end_it:
          end_params = params
        if mid_it is None and loss < mid_thresh:
          mid_it = i
          mid_params = params

        if aux is not None:
            pbar.set_description(f"Loss {loss:.3e}, Aux: {aux:.3e}")
        else:
            pbar.set_description(f"Loss {loss:.3e}")

        loss_list.append(loss)
# Out:
# Loss 1.317e-06: 100%|████████████████████████| 500/500 [00:10<00:00, 48.84its/s]

# %%
plt.rcParams.update({'font.size': 14})
plt.rcParams.update({'axes.labelsize': 14})

plt.plot(loss_list)
#plt.axvline(start_it, color='black', linestyle='--')
#plt.axvline(mid_it, color='black', linestyle='--')
#plt.axvline(end_it, color='black', linestyle='--')

plt.yscale('log')
plt.xscale('log')
plt.xlabel("Training iterations")
plt.ylabel("Loss estimate")

#plt.savefig(f"NN_training.pdf", bbox_inches='tight')
# Out:
# Text(0, 0.5, 'Loss estimate')

# %% [markdown]
# ## Kaczmarz++ Algorithm

# %%
def get_kaczmarzpp_optimizer(params, rng, dummy_x, alpha, eta, lamb, p, accelerated=True):
    param_vec, unravel_fn = flatten_util.ravel_pytree(params)
    opt_state = []
    mtm = jnp.zeros_like(param_vec)

    # Momentum update parameters
    rho = 0.0
    mtm_param = 0.0 if not accelerated else (1 - rho) / (1 + rho)
    r_hat = 1.0
    checkpoint_idx = 1

    residuals = []

    def step(params, batch, targets, opt_state, rng, step_idx):
        nonlocal mtm, rho, r_hat, checkpoint_idx, mtm_param, alpha, residuals

        batch_size = batch.shape[0]

        predictions, jacobian = jacobian_fn(params, batch)
        residual = (targets - predictions)

        # Save normalized residual for adaptive momentum
        res_norm = jnp.linalg.norm(residual) / jnp.linalg.norm(targets)
        residuals.append(res_norm)

        loss = jnp.sum(residual**2) / batch_size
        
        jacobian /= jnp.sqrt(batch_size)
        residual /= jnp.sqrt(batch_size)

        T = jacobian @ jacobian.T + lamb * jnp.eye(batch_size)
        ravel_update = jacobian.T @ jax.scipy.linalg.solve(T, residual, assume_a="pos") # Equivalent to finding w

        # Apply momentum and update
        if not accelerated:
            ravel_step = ravel_update
        else:
            mtm = mtm_param * (mtm - ravel_update)
            ravel_step = ravel_update + eta * mtm

        update = unravel_fn(ravel_step)
        params = jax.tree.map(lambda p, u: p + alpha * u, params, update)

        # Every p steps, update rho and mtm_param adaptively
        if accelerated and step_idx % p == 0 and step_idx >= 2 * p:
            eps_t = jnp.sum(jnp.array(residuals[step_idx - p:step_idx]) ** 2)
            eps_tp = jnp.sum(jnp.array(residuals[step_idx - 2*p:step_idx - p]) ** 2)
            r_ip = eps_t / eps_tp

            a_new = (checkpoint_idx + 1) ** jnp.log(checkpoint_idx + 1)
            a_old = checkpoint_idx ** jnp.log(checkpoint_idx)
            alph = a_old / a_new

            r_hat = alph * r_hat + (1 - alph) * jnp.minimum(1.0, r_ip)
            rho = jnp.maximum(0.0, 1 - r_hat ** (1 / p))
            mtm_param = (1 - rho) / (1 + rho)
            checkpoint_idx += 1

        return params, [], rng, loss, None

    return opt_state, jax.jit(step), rng

# %%
rng = jax.random.PRNGKey(seed)

alpha = 0.5 # Learning rate
eta = 0.5 # Momentum strength
lamb = 1e-2 # Regularization parameter
p = 10 # Lookback window for adaptive momentum
accelerated = False

num_it = 500

# Initialize model parameters and data
rng, key = jax.random.split(rng)
params = model_fn.init(key, dummy_x)

loss_list = []

# Initialize Kaczmarz++ optimizer
opt_state, opt_step, rng = get_kaczmarzpp_optimizer(params, rng, dummy_x, alpha, eta, lamb, p, accelerated)

batch_size = 500

start_it = 20
mid_thresh = 1e-2
mid_it = None
end_it = 2500

start_params = None
mid_params = None
end_params = None

# Training loop
with trange(num_it, unit="its", position=0, leave=True) as pbar:
    for i in pbar:
        rng, key = jax.random.split(rng)
        batch = jax.random.uniform(key, shape=(batch_size, 1))
        targets = target_fn(batch)[:, 0]

        params, opt_state, rng, loss, aux = opt_step(params, batch, targets, opt_state, rng, i)

        if i == start_it:
          start_params = params
        if i == end_it:
          end_params = params
        if mid_it is None and loss < mid_thresh:
          mid_it = i
          mid_params = params

        if aux is not None:
            pbar.set_description(f"Loss {loss:.3e}, Aux: {aux:.3e}")
        else:
            pbar.set_description(f"Loss {loss:.3e}")

        loss_list.append(loss)
# Out:
# Loss 1.317e-06: 100%|████████████████████████| 500/500 [00:09<00:00, 54.19its/s]

# %%
plt.rcParams.update({'font.size': 14})
plt.rcParams.update({'axes.labelsize': 14})

plt.plot(loss_list)
#plt.axvline(start_it, color='black', linestyle='--')
#plt.axvline(mid_it, color='black', linestyle='--')
#plt.axvline(end_it, color='black', linestyle='--')

plt.yscale('log')
plt.xscale('log')
plt.xlabel("Training iterations")
plt.ylabel("Loss estimate")

#plt.savefig(f"NN_training.pdf", bbox_inches='tight')
# Out:
# Text(0, 0.5, 'Loss estimate')

# %% [markdown]
# ## SPRING (clean)

# %%
def get_spring_optimizer_clean(params, rng, dummy_x, eta, beta, lamb):    
    param_vec, unravel_fn = flatten_util.ravel_pytree(params)
    phi = jnp.zeros_like(param_vec)
    opt_state = SpringCleanState(phi)
    
    def step(params, batch, targets, opt_state, rng):
        phi = opt_state.phi
    
        batch_size = batch.shape[0]
        predictions, jacobian = jacobian_fn(params, batch)
        residual = targets - predictions

        loss = jnp.sum(residual ** 2) / batch_size

        correction = residual - jacobian @ (beta * phi)

        jacobian /= jnp.sqrt(batch_size)
        correction /= jnp.sqrt(batch_size)

        T = jacobian @ jacobian.T + lamb * jnp.eye(batch_size)
        delta_phi = jacobian.T @ jax.scipy.linalg.solve(T, correction, assume_a="pos")
        
        phi = beta * phi + delta_phi

        update = unravel_fn(phi)        
        params = jax.tree.map(lambda p, u: p + eta * u, params, update)

        opt_state = SpringCleanState(phi)
        
        return params, opt_state, rng, loss, None

    return opt_state, jax.jit(step), rng

# %%
rng = jax.random.PRNGKey(seed)

lamb = 1e-2 #regularization parameter, same as in Kaczmarz
eta = 0.5 #learning rate 
beta = 0

num_it = 500

rng, key = jax.random.split(rng)
params = model_fn.init(key, dummy_x)

loss_list = []

opt_state, opt_step, rng  = get_spring_optimizer_clean(params, rng, dummy_x, eta, beta, lamb)

batch_size = 500

start_it = 20
mid_thresh = 1e-2
mid_it = None
end_it = 2500

start_params = None
mid_params = None
end_params = None

# Training loop
with trange(num_it, unit="its", position=0, leave=True) as pbar:
    for i in pbar:
        rng, key = jax.random.split(rng)
        batch = jax.random.uniform(key, shape=(batch_size, 1))
        targets = target_fn(batch)[:, 0]

        params, opt_state, rng, loss, aux = opt_step(params, batch, targets, opt_state, rng)

        if i == start_it:
          start_params = params
        if i == end_it:
          end_params = params
        if mid_it is None and loss < mid_thresh:
          mid_it = i
          mid_params = params

        if aux is not None:
            pbar.set_description(f"Loss {loss:.3e}, Aux: {aux:.3e}")
        else:
            pbar.set_description(f"Loss {loss:.3e}")

        loss_list.append(loss)

loss_list_clean = loss_list
# Out:
# Loss 9.545e-07: 100%|████████████████████████| 500/500 [00:09<00:00, 51.79its/s]

# %%
plt.rcParams.update({'font.size': 14})
plt.rcParams.update({'axes.labelsize': 14})

plt.plot(loss_list)
#plt.axvline(start_it, color='black', linestyle='--')
#plt.axvline(mid_it, color='black', linestyle='--')
#plt.axvline(end_it, color='black', linestyle='--')

plt.yscale('log')
plt.xscale('log')
plt.xlabel("Training iterations")
plt.ylabel("Loss estimate")

#plt.savefig(f"NN_training.pdf", bbox_inches='tight')
# Out:
# Text(0, 0.5, 'Loss estimate')

# %% [markdown]
# ## SPRING (Adaptive momentum)

# %%
def get_spring_optimizer(params, rng, dummy_x, eta, lamb, p):
    param_vec, unravel_fn = flatten_util.ravel_pytree(params)
    phi = jnp.zeros_like(param_vec)
    buffer = jnp.zeros(2 * p)
    buffer_index = jnp.array(0)
    r_hat = 1.0
    beta = 0.9 #!!!!!
    checkpoint_idx = 1
    
    opt_state = SpringState(phi, buffer, buffer_index, r_hat, beta, checkpoint_idx)
    
    def step(params, batch, targets, opt_state, rng, step_idx):
        phi, buffer, buffer_index, r_hat, beta, checkpoint_idx = opt_state

        batch_size = batch.shape[0]
        
        predictions, jacobian = jacobian_fn(params, batch)
        residual = targets - predictions

        # Save normalized residual for adaptive momentum
        res_norm = jnp.linalg.norm(residual) / jnp.linalg.norm(targets)
        buffer = buffer.at[buffer_index % (2 * p)].set(res_norm)
        buffer_index += 1        
        
        loss = jnp.sum(residual ** 2) / batch_size

        # Correction term: r - J @ (beta * phi)
        correction = residual - jacobian @ (beta * phi) # Residual and jacobian, and phi are all not normalized
        
        jacobian /= jnp.sqrt(batch_size)
        correction /= jnp.sqrt(batch_size)
        

        # Least-squares solve: minimize || J φ - correction ||^2
        # Solution: phi = beta * phi + J.T @ ( (J J.T)^-1 @ correction )
        T = jacobian @ jacobian.T + lamb * jnp.eye(batch_size) 
        delta_phi = jacobian.T @ jax.scipy.linalg.solve(T, correction, assume_a="pos") 
        phi = beta * phi + delta_phi

        # Parameter update
        update = unravel_fn(phi)
        params = jax.tree.map(lambda p, u: p + eta * u, params, update)
        
        #update beta
        def update_beta(step_idx, beta, r_hat, checkpoint_idx):
            def update_beta_fn(args):
                buffer, beta, r_hat, checkpoint_idx, buffer_index = args
                idxs_t = (buffer_index - jnp.arange(1, p + 1)) % (2 * p)
                idxs_tp = (buffer_index - jnp.arange(p + 1, 2 * p + 1)) % (2 * p)
                eps_t = jnp.sum(buffer[idxs_t] ** 2)
                eps_tp = jnp.sum(buffer[idxs_tp] ** 2)
                r_ip = eps_t / eps_tp
    
                a_new = (checkpoint_idx + 1) ** jnp.log(checkpoint_idx + 1)
                a_old = checkpoint_idx ** jnp.log(checkpoint_idx)
                alph = a_old / a_new
    
                r_hat_new = alph * r_hat + (1 - alph) * jnp.minimum(1.0, r_ip)
                rho = jnp.maximum(0.0, 1 - r_hat_new ** (1 / p))
                beta_new = (1 - rho) / (1 + rho)
                return beta_new, r_hat_new, checkpoint_idx + 1, rho

            def skip_update(args):
                _, beta, r_hat, checkpoint_idx, _ = args
                return beta, r_hat, checkpoint_idx, jnp.nan
    
            cond = jnp.logical_and(step_idx % p == 0, step_idx >= 2 * p)
            beta, r_hat, checkpoint_idx, rho = jax.lax.cond(cond, update_beta_fn, skip_update, operand=(buffer, beta, r_hat, checkpoint_idx, buffer_index))
            return beta, r_hat, checkpoint_idx, cond
        
        beta, r_hat, checkpoint_idx, cond = update_beta(step_idx, beta, r_hat, checkpoint_idx)
        opt_state = SpringState(phi, buffer, buffer_index, r_hat, beta, checkpoint_idx)
        return params, opt_state, rng, loss, None
            
    return opt_state, jax.jit(step), rng

# %%
def get_spring_optimizer_debug(params, rng, dummy_x, eta, lamb, p):
    param_vec, unravel_fn = flatten_util.ravel_pytree(params)
    phi = jnp.zeros_like(param_vec)
    buffer = jnp.zeros(2 * p)
    buffer_index = jnp.array(0)
    r_hat = 1.0
    beta = 0.9
    checkpoint_idx = 1
    
    opt_state = SpringState(phi, buffer, buffer_index, r_hat, beta, checkpoint_idx)
    
    def step(params, batch, targets, opt_state, rng, step_idx):
        phi, buffer, buffer_index, r_hat, beta, checkpoint_idx = opt_state
        batch_size = batch.shape[0]
        predictions, jacobian = jacobian_fn(params, batch)
        residual = targets - predictions
        
        # Save normalized residual for adaptive momentum
        res_norm = jnp.linalg.norm(residual) / jnp.linalg.norm(targets)
        buffer = buffer.at[buffer_index % (2 * p)].set(res_norm)
        buffer_index += 1
        
        loss = jnp.sum(residual ** 2) / batch_size
        
        # Correction term: r - J @ (beta * phi)
        correction = residual - jacobian @ (beta * phi)
        jacobian /= jnp.sqrt(batch_size)
        correction /= jnp.sqrt(batch_size)
        
        # Least-squares solve
        T = jacobian @ jacobian.T + lamb * jnp.eye(batch_size)
        delta_phi = jacobian.T @ jax.scipy.linalg.solve(T, correction, assume_a="pos")
        phi = beta * phi + delta_phi
        
        # Parameter update
        update = unravel_fn(phi)
        params = jax.tree.map(lambda p, u: p + eta * u, params, update)
        
        # Update beta adaptively - WITH DEBUGGING
        def update_beta_debug(step_idx, beta, r_hat, checkpoint_idx):
            def update_beta_fn(args):
                buffer, beta, r_hat, checkpoint_idx, buffer_index = args
                idxs_t = (buffer_index - jnp.arange(1, p + 1)) % (2 * p)
                idxs_tp = (buffer_index - jnp.arange(p + 1, 2 * p + 1)) % (2 * p)
                eps_t = jnp.sum(buffer[idxs_t] ** 2)
                eps_tp = jnp.sum(buffer[idxs_tp] ** 2)
                
                # Add small epsilon to avoid division by zero
                #eps_tp_safe = jnp.maximum(eps_tp, 1e-12)
                r_ip = eps_t / eps_tp
                
                a_new = (checkpoint_idx + 1) ** jnp.log(checkpoint_idx + 1)
                a_old = checkpoint_idx ** jnp.log(checkpoint_idx)
                alph = a_old / a_new
                r_hat_new = alph * r_hat + (1 - alph) * jnp.minimum(1.0, r_ip)
                rho = jnp.maximum(0.0, 1 - r_hat_new ** (1 / p))
                beta_new = (1 - rho) / (1 + rho)
                
                # Return debug info as well
                debug_info = {
                    'eps_t': eps_t,
                    'eps_tp': eps_tp, 
                    'r_ip': r_ip,
                    'r_hat_old': r_hat,
                    'r_hat_new': r_hat_new,
                    'rho': rho,
                    'beta_old': beta,
                    'beta_new': beta_new,
                    'alph': alph,
                    'checkpoint_idx': checkpoint_idx
                }
                
                return beta_new, r_hat_new, checkpoint_idx + 1, debug_info
            
            def skip_update(args):
                _, beta, r_hat, checkpoint_idx, _ = args
                # Return same structure as update_beta_fn but with dummy values
                dummy_debug_info = {
                    'eps_t': 0.0,
                    'eps_tp': 0.0, 
                    'r_ip': 0.0,
                    'r_hat_old': r_hat,
                    'r_hat_new': r_hat,
                    'rho': 0.0,
                    'beta_old': beta,
                    'beta_new': beta,
                    'alph': 0.0,
                    'checkpoint_idx': checkpoint_idx
                }
                return beta, r_hat, checkpoint_idx, dummy_debug_info
            
            # Check conditions
            cond1 = step_idx % p == 0
            cond2 = step_idx >= 2 * p
            cond = jnp.logical_and(cond1, cond2)
            
            beta, r_hat, checkpoint_idx, debug_info = jax.lax.cond(
                cond, update_beta_fn, skip_update,
                operand=(buffer, beta, r_hat, checkpoint_idx, buffer_index)
            )
            
            return beta, r_hat, checkpoint_idx, debug_info, cond1, cond2
        
        beta, r_hat, checkpoint_idx, debug_info, cond1, cond2 = update_beta_debug(step_idx, beta, r_hat, checkpoint_idx)
        
        opt_state = SpringState(phi, buffer, buffer_index, r_hat, beta, checkpoint_idx)
        aux = {
            'debug_info': debug_info,
            'cond1': cond1,  # step_idx % p == 0
            'cond2': cond2,  # step_idx >= 2 * p
            'step_idx': step_idx,
            'buffer_index': buffer_index,
            'res_norm': res_norm
        }
        return params, opt_state, rng, loss, aux
    
    return opt_state, jax.jit(step), rng

# %%
rng = jax.random.PRNGKey(seed)
lamb = 1e-2
eta = 0.5
p = 10
num_it = 500  # Full run

rng, key = jax.random.split(rng)
params = model_fn.init(key, dummy_x)
loss_list = []
beta_history = []
rho_history = []
update_iterations = []

opt_state, opt_step, rng = get_spring_optimizer_debug(params, rng, dummy_x, eta, lamb, p)
batch_size = 500

print("Running full training with β tracking...")

with trange(num_it, unit="its", position=0, leave=True) as pbar:
    for i in pbar:
        rng, key = jax.random.split(rng)
        batch = jax.random.uniform(key, shape=(batch_size, 1))
        targets = target_fn(batch)[:, 0]
        params, opt_state, rng, loss, aux = opt_step(params, batch, targets, opt_state, rng, i)
        
        current_beta = float(opt_state.beta)
        beta_history.append(current_beta)
        loss_list.append(loss)
        
        # Track when β actually changes
        if i > 0 and abs(current_beta - beta_history[-2]) > 1e-6:
            update_iterations.append(i)
        
        # Show β in progress bar
        if i >= 20 and i % 10 == 0:
            pbar.set_description(f"Loss {loss:.3e}, β: {current_beta:.3f}")
        else:
            pbar.set_description(f"Loss {loss:.3e}, β: {current_beta:.3f}")
loss_list_aa = loss_list
# Out:
# Running full training with β tracking...
# Loss 5.219e-09, β: 0.988: 100%|██████████████| 500/500 [00:09<00:00, 51.07its/s]

# %%
# Create the corrected visualization
plt.rcParams.update({'font.size': 14})
plt.rcParams.update({'axes.labelsize': 14})

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 10))

# Plot 1: Loss over time
ax1.plot(loss_list, 'b-', linewidth=1.5)
ax1.set_yscale('log')
ax1.set_xscale('log')
ax1.set_xlabel('Training iterations')
ax1.set_ylabel('Loss')
ax1.set_title('Training Loss')
ax1.grid(True, alpha=0.3)

# Plot 2: β evolution over time
ax2.plot(beta_history, 'r-', linewidth=2)
ax2.set_xlabel('Training iterations')
ax2.set_ylabel('β (momentum parameter)')
ax2.set_title('Evolution of Adaptive Momentum Parameter β')
ax2.grid(True, alpha=0.3)
ax2.set_ylim([0.6, 1.05])

# Highlight the update points
for update_iter in update_iterations:
    ax2.axvline(x=update_iter, color='gray', linestyle='--', alpha=0.5)

# Plot 3: β updates only (cleaner view)
beta_updates = [beta_history[i] for i in update_iterations]
ax3.plot(update_iterations, beta_updates, 'bo-', markersize=6, linewidth=2)
ax3.set_xlabel('Training iterations')
ax3.set_ylabel('β value')
ax3.set_title('β Updates (Adaptive Changes Only)')
ax3.grid(True, alpha=0.3)
ax3.set_ylim([0.6, 1.05])

# Plot 4: ρ evolution (momentum strength indicator)
ax4.plot(update_iterations, rho_history, 'go-', markersize=6, linewidth=2)
ax4.set_xlabel('Training iterations')
ax4.set_ylabel('ρ (momentum reduction factor)')
ax4.set_title('ρ Evolution (Higher ρ = Less Momentum)')
ax4.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 38
#      35 ax3.set_ylim([0.6, 1.05])
#      37 # Plot 4: ρ evolution (momentum strength indicator)
# ---> 38 ax4.plot(update_iterations, rho_history, 'go-', markersize=6, linewidth=2)
#      39 ax4.set_xlabel('Training iterations')
#      40 ax4.set_ylabel('ρ (momentum reduction factor)')
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
#    1687 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
#    1690     self.add_line(line)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/axes/_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/axes/_base.py:504, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     501     self.axes.yaxis.update_units(y)
#     503 if x.shape[0] != y.shape[0]:
# --> 504     raise ValueError(f"x and y must have same first dimension, but "
#     505                      f"have shapes {x.shape} and {y.shape}")
#     506 if x.ndim > 2 or y.ndim > 2:
#     507     raise ValueError(f"x and y can be no greater than 2D, but have "
#     508                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (47,) and (0,)

# %% [markdown]
# ## minSR (SPRING w/ beta = 0) VS SPRING (Adaptive Momentum)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# Left plot: Loss comparison
ax1.plot(loss_list_clean, label="SNGD", linewidth=2)
ax1.plot(loss_list_aa, label="SPRING (adaptive momentum)", linestyle="--", linewidth=2)
ax1.set_yscale('log')
ax1.set_xscale('log')
ax1.set_xlabel("Training iterations")
ax1.set_ylabel("Loss estimate")
ax1.legend()
ax1.grid(True, alpha=0.3)
ax1.set_title("Loss Comparison")

# Right plot: Beta evolution
ax2.plot(beta_history, color='red', linewidth=2)
ax2.set_xlabel("Training iterations")
ax2.set_ylabel("β (momentum parameter)")
ax2.set_title("β Evolution in Adaptive SPRING")
ax2.grid(True, alpha=0.3)
ax2.set_ylim([0.6, 1.05])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Comparing minSR and SPRING across eta values

# %%
eta_vals = [0.1, 0.3, 0.5, 0.7]
num_it = 1000
lamb = 1e-2
p = 10
batch_size = 500

minSR_losses = []
spring_adaptive_losses = []

for eta in eta_vals:
    print(f"minSR vs SPRING adaptive for eta = {eta}")
    
    # Re-initialize parameters for a fair comparison
    rng = jax.random.PRNGKey(seed)
    rng, key = jax.random.split(rng)
    params = model_fn.init(key, dummy_x)

    # minSR
    params_clean = params
    loss_list_clean = []
    opt_state_clean, opt_step_clean, rng_clean = get_spring_optimizer_clean(params_clean, rng, dummy_x, eta, beta=0, lamb=lamb)

    with trange(num_it, unit="its", position=0, leave=True) as pbar:
        for i in pbar:
            rng_clean, key = jax.random.split(rng_clean)
            batch = jax.random.uniform(key, shape=(batch_size, 1))
            targets = target_fn(batch)[:, 0]
            params_clean, opt_state_clean, rng_clean, loss, _ = opt_step_clean(params_clean, batch, targets, opt_state_clean, rng_clean)
            loss_list_clean.append(loss)

    minSR_losses.append(loss_list_clean)

    # SPRING adaptive
    params_adaptive = params
    loss_list_adaptive = []
    opt_state_adaptive, opt_step_adaptive, rng_adaptive = get_spring_optimizer(params_adaptive, rng, dummy_x, eta, lamb, p)

    with trange(num_it, unit="its", position=0, leave=True) as pbar:
        for i in pbar:
            rng, key = jax.random.split(rng)
            batch = jax.random.uniform(key, shape=(batch_size, 1))
            targets = target_fn(batch)[:, 0]
            params, opt_state_adaptive, rng, loss, _ = opt_step_adaptive(params, batch, targets, opt_state_adaptive, rng, i)
            
            current_beta = float(opt_state_adaptive.beta)
            loss_list_adaptive.append(loss)

            # Show β in progress bar
            if i >= 20 and i % 10 == 0:
                pbar.set_description(f"Loss {loss:.3e}, β: {current_beta:.3f}")
            else:
                pbar.set_description(f"Loss {loss:.3e}, β: {current_beta:.3f}")


    spring_adaptive_losses.append(loss_list_adaptive)
# Out:
# minSR vs SPRING adaptive for eta = 0.1
# 100%|██████████████████████████████████████| 1000/1000 [00:23<00:00, 42.70its/s]
# Loss 1.689e-07, β: 0.991: 100%|████████████| 1000/1000 [00:22<00:00, 43.90its/s]
# minSR vs SPRING adaptive for eta = 0.3
# 100%|██████████████████████████████████████| 1000/1000 [00:21<00:00, 45.99its/s]
# Loss 8.981e-08, β: 0.994: 100%|████████████| 1000/1000 [00:24<00:00, 40.57its/s]
# minSR vs SPRING adaptive for eta = 0.5
# 100%|██████████████████████████████████████| 1000/1000 [00:22<00:00, 45.05its/s]
# Loss 5.546e-09, β: 0.993: 100%|████████████| 1000/1000 [00:26<00:00, 37.75its/s]
# minSR vs SPRING adaptive for eta = 0.7
# 100%|██████████████████████████████████████| 1000/1000 [00:22<00:00, 43.48its/s]
# Loss 1.370e-07, β: 0.994: 100%|████████████| 1000/1000 [00:21<00:00, 47.21its/s]

# %%
plt.rcParams.update({'font.size': 14})
plt.figure(figsize=(16, 10))

for idx, eta in enumerate(eta_vals):
    plt.subplot(2, 2, idx + 1)
    plt.plot(minSR_losses[idx], label="SNGD", linestyle="--")
    plt.plot(spring_adaptive_losses[idx], label="SPRING (adaptive)", color="tab:orange")
    plt.yscale('log')
    plt.xscale('log')
    plt.xlabel("Iterations")
    plt.ylabel("Loss")
    plt.title(f"η = {eta}")
    plt.legend(loc="lower left")
    plt.grid(True)

plt.tight_layout()
plt.suptitle("SNGD and SPRING Comparison for Different η", y=1.02, fontsize=16)
# plt.savefig("spring_eta_comparison.pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Comparing best eta vs best eta

# %% [markdown]
# ### Finding best eta for minSR

# %%
eta_vals = [0.5, 0.6, 0.7]
num_it = 1000
lamb = 1e-2
batch_size = 500

minSR_losses = []

for eta in eta_vals:
    print(f"minSR for eta value {eta}")

    # Re-initialize parameters for a fair comparison
    rng = jax.random.PRNGKey(seed)
    rng, key = jax.random.split(rng)
    params = model_fn.init(key, dummy_x)

    # minSR
    params_clean = params
    loss_list_clean = []
    opt_state_clean, opt_step_clean, rng_clean = get_spring_optimizer_clean(params_clean, rng, dummy_x, eta, beta=0, lamb=lamb)

    with trange(num_it, unit="its", position=0, leave=True) as pbar:
        for i in pbar:
            rng_clean, key = jax.random.split(rng_clean)
            batch = jax.random.uniform(key, shape=(batch_size, 1))
            targets = target_fn(batch)[:, 0]
            params_clean, opt_state_clean, rng_clean, loss, _ = opt_step_clean(params_clean, batch, targets, opt_state_clean, rng_clean)
            loss_list_clean.append(loss)

    minSR_losses.append(loss_list_clean)
# Out:
# minSR for eta value 0.5
# 100%|██████████████████████████████████████| 1000/1000 [00:19<00:00, 51.32its/s]
# minSR for eta value 0.6
# 100%|██████████████████████████████████████| 1000/1000 [00:19<00:00, 50.49its/s]
# minSR for eta value 0.7
# 100%|██████████████████████████████████████| 1000/1000 [00:19<00:00, 50.98its/s]

# %%
plt.figure(figsize=(8, 5))
for i, eta in enumerate(eta_vals):
    plt.plot(minSR_losses[i], label=f"η = {eta}")

plt.yscale("log")
plt.xscale("log")
plt.xlabel("Training iterations")
plt.ylabel("Loss estimate")
plt.title("minSR across η values")
plt.legend()
plt.grid(True)
# Optional: plt.savefig("minSR_eta_comparison.pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Finding best eta for SPRING

# %%
num_it = 1000
lamb = 1e-2
batch_size = 500
eta_vals = [0.1, 0.3, 0.5, 0.6, 0.7]
p = 10

spring_adaptive_losses = []

for eta in eta_vals:
    print(f"SPRING for eta value {eta}")

    # Re-initialize parameters for a fair comparison
    rng = jax.random.PRNGKey(seed)
    rng, key = jax.random.split(rng)
    params = model_fn.init(key, dummy_x)

    # SPRING adaptive
    params_adaptive = params
    loss_list_adaptive = []
    opt_state_adaptive, opt_step_adaptive, rng_adaptive = get_spring_optimizer(params_adaptive, rng, dummy_x, eta, lamb, p)

    with trange(num_it, unit="its", position=0, leave=True) as pbar:
        for i in pbar:
            rng, key = jax.random.split(rng)
            batch = jax.random.uniform(key, shape=(batch_size, 1))
            targets = target_fn(batch)[:, 0]
            params, opt_state_adaptive, rng, loss, _ = opt_step_adaptive(params, batch, targets, opt_state_adaptive, rng, i)
            
            current_beta = float(opt_state_adaptive.beta)
            loss_list_adaptive.append(loss)

            # Show β in progress bar
            if i >= 20 and i % 10 == 0:
                pbar.set_description(f"Loss {loss:.3e}, β: {current_beta:.3f}")
            else:
                pbar.set_description(f"Loss {loss:.3e}, β: {current_beta:.3f}")


    spring_adaptive_losses.append(loss_list_adaptive)

# %%
plt.figure(figsize=(8, 5))
for i, eta in enumerate(eta_vals):
    plt.plot(spring_adaptive_losses[i], label=f"η = {eta}")

plt.yscale("log")
plt.xscale("log")
plt.xlabel("Training iterations")
plt.ylabel("Loss estimate")
plt.title("SRPING across η values")
plt.legend()
plt.grid(True)
# Optional: plt.savefig("minSR_eta_comparison.pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# ### best eta vs best eta

# %%
rng = jax.random.PRNGKey(seed)

lamb = 1e-2 #regularization parameter, same as in Kaczmarz
minSR_eta = 0.6 #learning rate 
beta = 0

num_it = 3000

rng, key = jax.random.split(rng)
params = model_fn.init(key, dummy_x)

loss_list = []

opt_state, opt_step, rng  = get_spring_optimizer_clean(params, rng, dummy_x, minSR_eta, beta, lamb)

batch_size = 500

start_it = 20
mid_thresh = 1e-2
mid_it = None
end_it = 2500

start_params = None
mid_params = None
end_params = None

# Training loop
with trange(num_it, unit="its", position=0, leave=True) as pbar:
    for i in pbar:
        rng, key = jax.random.split(rng)
        batch = jax.random.uniform(key, shape=(batch_size, 1))
        targets = target_fn(batch)[:, 0]

        params, opt_state, rng, loss, aux = opt_step(params, batch, targets, opt_state, rng)

        if i == start_it:
          start_params = params
        if i == end_it:
          end_params = params
        if mid_it is None and loss < mid_thresh:
          mid_it = i
          mid_params = params

        if aux is not None:
            pbar.set_description(f"Loss {loss:.3e}, Aux: {aux:.3e}")
        else:
            pbar.set_description(f"Loss {loss:.3e}")

        loss_list.append(loss)

loss_list_clean = loss_list
# Out:
# Loss 2.664e-07: 100%|██████████████████████| 3000/3000 [01:04<00:00, 46.83its/s]

# %%
rng = jax.random.PRNGKey(seed)

lamb = 1e-2 #regularization parameter, same as in Kaczmarz
spring_eta =  0.5 #learning rate 
p = 10

num_it = 3000

rng, key = jax.random.split(rng)
params = model_fn.init(key, dummy_x)

loss_list = []

opt_state, opt_step, rng  = get_spring_optimizer(params, rng, dummy_x, spring_eta, lamb, p)

batch_size = 500

start_it = 20
mid_thresh = 1e-2
mid_it = None
end_it = 2500

start_params = None
mid_params = None
end_params = None

# Training loop
with trange(num_it, unit="its", position=0, leave=True) as pbar:
    for i in pbar:
        rng, key = jax.random.split(rng)
        batch = jax.random.uniform(key, shape=(batch_size, 1))
        targets = target_fn(batch)[:, 0]

        params, opt_state, rng, loss, aux = opt_step(params, batch, targets, opt_state, rng, i)

        if i == start_it:
          start_params = params
        if i == end_it:
          end_params = params
        if mid_it is None and loss < mid_thresh:
          mid_it = i
          mid_params = params

        if aux is not None:
            pbar.set_description(f"Loss {loss:.3e}, Aux: {aux:.3e}")
        else:
            pbar.set_description(f"Loss {loss:.3e}")

        loss_list.append(loss)

loss_list_aa = loss_list
# Out:
# Loss 5.981e-10: 100%|██████████████████████| 3000/3000 [01:08<00:00, 43.59its/s]

# %%
plt.rcParams.update({'font.size': 14})
plt.rcParams.update({'axes.labelsize': 14})

plt.figure(figsize=(8, 5))
plt.plot(loss_list_clean, label=f"MinSR (eta = {minSR_eta}, lambda = 1e-2)")
plt.plot(loss_list_aa, label=f"Adaptive SPRING (eta = {spring_eta}, lambda = 1e-2)", linestyle="--")

plt.yscale('log')
plt.xscale('log')
plt.xlabel("Training iterations")
plt.ylabel("Loss estimate")
plt.legend()
plt.grid(True)
plt.title("SNGD vs Adaptive SPRING with Tuned η")

# Optional: save to file
# plt.savefig("SPRING_comparison.pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Testing whether adaptive beta is the best

# %%
#beta_vals = [0.86, 0.85, 0.84]
#beta_vals = [0.95, 0.9, 0.87, 0.85]
beta_vals = [0, 0.5, 0.7, 0.85, 0.9, 0.99]
#beta_vals = [0.855, 0.95]
num_it = 1000
lamb = 1e-2
batch_size = 500
eta = 0.5

spring_losses = []

for beta in beta_vals:
    print(f"SPRING for beta value {beta}")

    # Re-initialize parameters for a fair comparison
    rng = jax.random.PRNGKey(seed)
    rng, key = jax.random.split(rng)
    params = model_fn.init(key, dummy_x)

    # SPRING
    loss_list_clean = []
    opt_state_clean, opt_step_clean, rng_clean = get_spring_optimizer_clean(params, rng, dummy_x, eta, beta, lamb=lamb)

    with trange(num_it, unit="its", position=0, leave=True) as pbar:
        for i in pbar:
            rng_clean, key = jax.random.split(rng_clean)
            batch = jax.random.uniform(key, shape=(batch_size, 1))
            targets = target_fn(batch)[:, 0]
            params, opt_state_clean, rng_clean, loss, _ = opt_step_clean(params, batch, targets, opt_state_clean, rng_clean)
            loss_list_clean.append(loss)

    spring_losses.append(loss_list_clean)
# Out:
# SPRING for beta value 0
# 100%|██████████████████████████████████████| 1000/1000 [00:19<00:00, 52.56its/s]
# SPRING for beta value 0.5
# 100%|██████████████████████████████████████| 1000/1000 [00:18<00:00, 54.78its/s]
# SPRING for beta value 0.7
# 100%|██████████████████████████████████████| 1000/1000 [00:18<00:00, 53.76its/s]
# SPRING for beta value 0.85
# 100%|██████████████████████████████████████| 1000/1000 [00:18<00:00, 52.64its/s]
# SPRING for beta value 0.9
# 100%|██████████████████████████████████████| 1000/1000 [00:18<00:00, 54.85its/s]
# SPRING for beta value 0.99
# 100%|██████████████████████████████████████| 1000/1000 [00:18<00:00, 54.51its/s]

# %%
rng = jax.random.PRNGKey(seed)
lamb = 1e-2
eta = 0.5
p = 10
num_it = 1000  # Full run

rng, key = jax.random.split(rng)
params = model_fn.init(key, dummy_x)
loss_list = []
beta_history = []
rho_history = []
update_iterations = []

opt_state, opt_step, rng = get_spring_optimizer(params, rng, dummy_x, eta, lamb, p)
batch_size = 500

print("Running full training with β tracking...")

with trange(num_it, unit="its", position=0, leave=True) as pbar:
    for i in pbar:
        rng, key = jax.random.split(rng)
        batch = jax.random.uniform(key, shape=(batch_size, 1))
        targets = target_fn(batch)[:, 0]
        params, opt_state, rng, loss, _ = opt_step(params, batch, targets, opt_state, rng, i)
        
        current_beta = float(opt_state.beta)
        beta_history.append(current_beta)
        loss_list.append(loss)
        
        # Track when β actually changes
        if i > 0 and abs(current_beta - beta_history[-2]) > 1e-6:
            update_iterations.append(i)
        
        # Show β in progress bar
        if i >= 20 and i % 10 == 0:
            pbar.set_description(f"Loss {loss:.3e}, β: {current_beta:.3f}")
        else:
            pbar.set_description(f"Loss {loss:.3e}, β: {current_beta:.3f}")
loss_list_aa = loss_list
# Out:
# Running full training with β tracking...
# Loss 1.382e-08, β: 0.991: 100%|████████████| 1000/1000 [00:20<00:00, 48.17its/s]

# %%
spring_losses.pop(-1)
# Out:
# [Array(2.5070095, dtype=float32),
#  Array(0.8670309, dtype=float32),
#  Array(0.2984622, dtype=float32),
#  Array(0.3329434, dtype=float32),
#  Array(0.5833471, dtype=float32),
#  Array(0.36305112, dtype=float32),
#  Array(0.24891886, dtype=float32),
#  Array(0.16255222, dtype=float32),
#  Array(0.18643472, dtype=float32),
#  Array(0.17683047, dtype=float32),
#  Array(0.1455377, dtype=float32),
#  Array(0.10897801, dtype=float32),
#  Array(0.11935491, dtype=float32),
#  Array(0.11898463, dtype=float32),
#  Array(0.14656278, dtype=float32),
#  Array(0.17756742, dtype=float32),
#  Array(0.20404594, dtype=float32),
#  Array(0.19880931, dtype=float32),
#  Array(0.48890415, dtype=float32),
#  Array(0.40831488, dtype=float32),
#  Array(0.36310318, dtype=float32),
#  Array(1.2878478, dtype=float32),
#  Array(2.008016, dtype=float32),
#  Array(0.9620684, dtype=float32),
#  Array(0.46530682, dtype=float32),
#  Array(0.2656294, dtype=float32),
#  Array(0.17605579, dtype=float32),
#  Array(0.13493627, dtype=float32),
#  Array(0.10537837, dtype=float32),
#  Array(0.27044797, dtype=float32),
#  Array(0.13345133, dtype=float32),
#  Array(0.41234165, dtype=float32),
#  Array(0.30108118, dtype=float32),
#  Array(0.14172561, dtype=float32),
#  Array(0.08957848, dtype=float32),
#  Array(0.05505074, dtype=float32),
#  Array(0.01533748, dtype=float32),
#  Array(0.02490328, dtype=float32),
#  Array(0.01177002, dtype=float32),
#  Array(0.01477464, dtype=float32),
#  Array(0.01811652, dtype=float32),
#  Array(0.01488774, dtype=float32),
#  Array(0.01010999, dtype=float32),
#  Array(0.00439267, dtype=float32),
#  Array(0.00284172, dtype=float32),
#  Array(0.00182311, dtype=float32),
#  Array(0.00127009, dtype=float32),
#  Array(0.00055184, dtype=float32),
#  Array(0.00028732, dtype=float32),
#  Array(0.00013089, dtype=float32),
#  Array(7.3131145e-05, dtype=float32),
#  Array(5.5554647e-05, dtype=float32),
#  Array(4.0411935e-05, dtype=float32),
#  Array(3.4807246e-05, dtype=float32),
#  Array(2.5992647e-05, dtype=float32),
#  Array(2.004013e-05, dtype=float32),
#  Array(1.8690376e-05, dtype=float32),
#  Array(1.5087097e-05, dtype=float32),
#  Array(1.5179118e-05, dtype=float32),
#  Array(1.4239766e-05, dtype=float32),
#  Array(1.1818918e-05, dtype=float32),
#  Array(1.0940365e-05, dtype=float32),
#  Array(1.162661e-05, dtype=float32),
#  Array(1.23091895e-05, dtype=float32),
#  Array(1.0385423e-05, dtype=float32),
#  Array(1.12561165e-05, dtype=float32),
#  Array(1.0101164e-05, dtype=float32),
#  Array(1.0425989e-05, dtype=float32),
#  Array(1.0126678e-05, dtype=float32),
#  Array(9.025969e-06, dtype=float32),
#  Array(9.450507e-06, dtype=float32),
#  Array(9.748822e-06, dtype=float32),
#  Array(1.0454215e-05, dtype=float32),
#  Array(9.981917e-06, dtype=float32),
#  Array(8.345442e-06, dtype=float32),
#  Array(8.069979e-06, dtype=float32),
#  Array(8.709292e-06, dtype=float32),
#  Array(8.750967e-06, dtype=float32),
#  Array(8.847798e-06, dtype=float32),
#  Array(7.814683e-06, dtype=float32),
#  Array(8.629584e-06, dtype=float32),
#  Array(7.636831e-06, dtype=float32),
#  Array(6.9313937e-06, dtype=float32),
#  Array(6.663085e-06, dtype=float32),
#  Array(7.784578e-06, dtype=float32),
#  Array(7.0015944e-06, dtype=float32),
#  Array(6.4526057e-06, dtype=float32),
#  Array(5.8394808e-06, dtype=float32),
#  Array(5.9190015e-06, dtype=float32),
#  Array(6.1504247e-06, dtype=float32),
#  Array(5.9807603e-06, dtype=float32),
#  Array(6.1219966e-06, dtype=float32),
#  Array(5.8941077e-06, dtype=float32),
#  Array(6.4404844e-06, dtype=float32),
#  Array(5.593068e-06, dtype=float32),
#  Array(5.7970465e-06, dtype=float32),
#  Array(5.395766e-06, dtype=float32),
#  Array(5.8752285e-06, dtype=float32),
#  Array(5.8492883e-06, dtype=float32),
#  Array(5.412487e-06, dtype=float32),
#  Array(4.2104703e-06, dtype=float32),
#  Array(4.5985125e-06, dtype=float32),
#  Array(4.743458e-06, dtype=float32),
#  Array(4.128453e-06, dtype=float32),
#  Array(4.714922e-06, dtype=float32),
#  Array(4.3018663e-06, dtype=float32),
#  Array(4.250153e-06, dtype=float32),
#  Array(3.7976808e-06, dtype=float32),
#  Array(3.6681076e-06, dtype=float32),
#  Array(3.6806932e-06, dtype=float32),
#  Array(4.588547e-06, dtype=float32),
#  Array(3.4124257e-06, dtype=float32),
#  Array(4.031104e-06, dtype=float32),
#  Array(3.7745476e-06, dtype=float32),
#  Array(2.8245106e-06, dtype=float32),
#  Array(3.1400114e-06, dtype=float32),
#  Array(2.8009924e-06, dtype=float32),
#  Array(3.1409606e-06, dtype=float32),
#  Array(3.1863644e-06, dtype=float32),
#  Array(3.3816382e-06, dtype=float32),
#  Array(3.574192e-06, dtype=float32),
#  Array(2.894493e-06, dtype=float32),
#  Array(2.5793643e-06, dtype=float32),
#  Array(3.0516746e-06, dtype=float32),
#  Array(2.5398137e-06, dtype=float32),
#  Array(3.2108405e-06, dtype=float32),
#  Array(2.62706e-06, dtype=float32),
#  Array(2.3206558e-06, dtype=float32),
#  Array(2.833332e-06, dtype=float32),
#  Array(2.5238535e-06, dtype=float32),
#  Array(2.2211586e-06, dtype=float32),
#  Array(2.1305707e-06, dtype=float32),
#  Array(2.394243e-06, dtype=float32),
#  Array(2.3802215e-06, dtype=float32),
#  Array(2.322401e-06, dtype=float32),
#  Array(2.195999e-06, dtype=float32),
#  Array(2.1147268e-06, dtype=float32),
#  Array(1.8839495e-06, dtype=float32),
#  Array(1.9961935e-06, dtype=float32),
#  Array(2.1216001e-06, dtype=float32),
#  Array(1.8900525e-06, dtype=float32),
#  Array(2.0031912e-06, dtype=float32),
#  Array(1.9122174e-06, dtype=float32),
#  Array(1.8276851e-06, dtype=float32),
#  Array(1.8900753e-06, dtype=float32),
#  Array(1.5648349e-06, dtype=float32),
#  Array(1.9408365e-06, dtype=float32),
#  Array(1.6233544e-06, dtype=float32),
#  Array(1.7902029e-06, dtype=float32),
#  Array(1.5496596e-06, dtype=float32),
#  Array(1.7611467e-06, dtype=float32),
#  Array(1.6213414e-06, dtype=float32),
#  Array(1.6157919e-06, dtype=float32),
#  Array(1.6313784e-06, dtype=float32),
#  Array(1.3491195e-06, dtype=float32),
#  Array(1.5561903e-06, dtype=float32),
#  Array(1.5970697e-06, dtype=float32),
#  Array(1.5925542e-06, dtype=float32),
#  Array(1.5286028e-06, dtype=float32),
#  Array(1.5640803e-06, dtype=float32),
#  Array(1.1243793e-06, dtype=float32),
#  Array(1.45992e-06, dtype=float32),
#  Array(1.5402254e-06, dtype=float32),
#  Array(1.268281e-06, dtype=float32),
#  Array(1.2501483e-06, dtype=float32),
#  Array(1.1505401e-06, dtype=float32),
#  Array(1.3948526e-06, dtype=float32),
#  Array(1.3588033e-06, dtype=float32),
#  Array(1.2892987e-06, dtype=float32),
#  Array(1.1996507e-06, dtype=float32),
#  Array(1.2837023e-06, dtype=float32),
#  Array(1.1243814e-06, dtype=float32),
#  Array(1.260516e-06, dtype=float32),
#  Array(1.1349375e-06, dtype=float32),
#  Array(1.2441494e-06, dtype=float32),
#  Array(1.050105e-06, dtype=float32),
#  Array(1.1913629e-06, dtype=float32),
#  Array(1.3838959e-06, dtype=float32),
#  Array(1.2735135e-06, dtype=float32),
#  Array(8.4240025e-07, dtype=float32),
#  Array(9.3177766e-07, dtype=float32),
#  Array(1.09972e-06, dtype=float32),
#  Array(9.443025e-07, dtype=float32),
#  Array(1.0775282e-06, dtype=float32),
#  Array(1.1762535e-06, dtype=float32),
#  Array(8.8665803e-07, dtype=float32),
#  Array(8.8057783e-07, dtype=float32),
#  Array(1.0213787e-06, dtype=float32),
#  Array(9.2970873e-07, dtype=float32),
#  Array(9.789053e-07, dtype=float32),
#  Array(9.093479e-07, dtype=float32),
#  Array(8.893484e-07, dtype=float32),
#  Array(8.085906e-07, dtype=float32),
#  Array(7.9798366e-07, dtype=float32),
#  Array(9.551081e-07, dtype=float32),
#  Array(8.210395e-07, dtype=float32),
#  Array(7.9429736e-07, dtype=float32),
#  Array(9.541419e-07, dtype=float32),
#  Array(7.0513664e-07, dtype=float32),
#  Array(8.497987e-07, dtype=float32),
#  Array(8.6974023e-07, dtype=float32),
#  Array(8.204473e-07, dtype=float32),
#  Array(7.0538454e-07, dtype=float32),
#  Array(8.898885e-07, dtype=float32),
#  Array(6.528707e-07, dtype=float32),
#  Array(6.306831e-07, dtype=float32),
#  Array(7.385726e-07, dtype=float32),
#  Array(7.439387e-07, dtype=float32),
#  Array(6.766803e-07, dtype=float32),
#  Array(7.3265034e-07, dtype=float32),
#  Array(6.0252967e-07, dtype=float32),
#  Array(6.1008876e-07, dtype=float32),
#  Array(6.5978713e-07, dtype=float32),
#  Array(6.6333604e-07, dtype=float32),
#  Array(6.1941984e-07, dtype=float32),
#  Array(5.9650483e-07, dtype=float32),
#  Array(6.4260263e-07, dtype=float32),
#  Array(5.904896e-07, dtype=float32),
#  Array(6.740624e-07, dtype=float32),
#  Array(6.2109496e-07, dtype=float32),
#  Array(4.897227e-07, dtype=float32),
#  Array(6.0144566e-07, dtype=float32),
#  Array(5.839295e-07, dtype=float32),
#  Array(5.86696e-07, dtype=float32),
#  Array(5.556971e-07, dtype=float32),
#  Array(5.8748907e-07, dtype=float32),
#  Array(4.93599e-07, dtype=float32),
#  Array(5.868615e-07, dtype=float32),
#  Array(5.956309e-07, dtype=float32),
#  Array(4.970974e-07, dtype=float32),
#  Array(5.116927e-07, dtype=float32),
#  Array(5.138561e-07, dtype=float32),
#  Array(4.6297723e-07, dtype=float32),
#  Array(4.3911285e-07, dtype=float32),
#  Array(4.521569e-07, dtype=float32),
#  Array(4.1918554e-07, dtype=float32),
#  Array(4.511294e-07, dtype=float32),
#  Array(4.3461688e-07, dtype=float32),
#  Array(4.1148232e-07, dtype=float32),
#  Array(4.450638e-07, dtype=float32),
#  Array(4.3568548e-07, dtype=float32),
#  Array(5.0909733e-07, dtype=float32),
#  Array(4.6863275e-07, dtype=float32),
#  Array(3.947092e-07, dtype=float32),
#  Array(4.0268444e-07, dtype=float32),
#  Array(4.6951058e-07, dtype=float32),
#  Array(4.787763e-07, dtype=float32),
#  Array(3.2523047e-07, dtype=float32),
#  Array(3.4577786e-07, dtype=float32),
#  Array(4.610561e-07, dtype=float32),
#  Array(3.8428587e-07, dtype=float32),
#  Array(3.5715982e-07, dtype=float32),
#  Array(3.3135936e-07, dtype=float32),
#  Array(4.0065157e-07, dtype=float32),
#  Array(4.610837e-07, dtype=float32),
#  Array(3.7350875e-07, dtype=float32),
#  Array(2.9264166e-07, dtype=float32),
#  Array(3.976922e-07, dtype=float32),
#  Array(3.4830757e-07, dtype=float32),
#  Array(3.329375e-07, dtype=float32),
#  Array(3.3350537e-07, dtype=float32),
#  Array(3.4016475e-07, dtype=float32),
#  Array(3.366154e-07, dtype=float32),
#  Array(3.1653235e-07, dtype=float32),
#  Array(3.4330498e-07, dtype=float32),
#  Array(3.7602672e-07, dtype=float32),
#  Array(2.5404142e-07, dtype=float32),
#  Array(3.166301e-07, dtype=float32),
#  Array(2.7518428e-07, dtype=float32),
#  Array(3.0146907e-07, dtype=float32),
#  Array(3.098816e-07, dtype=float32),
#  Array(3.4606362e-07, dtype=float32),
#  Array(2.8367563e-07, dtype=float32),
#  Array(3.07239e-07, dtype=float32),
#  Array(2.7379275e-07, dtype=float32),
#  Array(3.320905e-07, dtype=float32),
#  Array(2.8032412e-07, dtype=float32),
#  Array(2.926162e-07, dtype=float32),
#  Array(2.6532507e-07, dtype=float32),
#  Array(2.5749014e-07, dtype=float32),
#  Array(2.651668e-07, dtype=float32),
#  Array(2.5225157e-07, dtype=float32),
#  Array(2.4669524e-07, dtype=float32),
#  Array(2.6072118e-07, dtype=float32),
#  Array(2.48361e-07, dtype=float32),
#  Array(2.2796179e-07, dtype=float32),
#  Array(2.5200364e-07, dtype=float32),
#  Array(2.4959584e-07, dtype=float32),
#  Array(2.5554309e-07, dtype=float32),
#  Array(2.2384744e-07, dtype=float32),
#  Array(2.1692665e-07, dtype=float32),
#  Array(1.9598568e-07, dtype=float32),
#  Array(2.2487289e-07, dtype=float32),
#  Array(2.045216e-07, dtype=float32),
#  Array(2.3040515e-07, dtype=float32),
#  Array(2.2734653e-07, dtype=float32),
#  Array(1.7223672e-07, dtype=float32),
#  Array(2.2370901e-07, dtype=float32),
#  Array(2.1271906e-07, dtype=float32),
#  Array(2.1302995e-07, dtype=float32),
#  Array(1.8395488e-07, dtype=float32),
#  Array(2.0219925e-07, dtype=float32),
#  Array(1.852421e-07, dtype=float32),
#  Array(1.7810706e-07, dtype=float32),
#  Array(2.193266e-07, dtype=float32),
#  Array(2.0077252e-07, dtype=float32),
#  Array(1.8083676e-07, dtype=float32),
#  Array(1.8568025e-07, dtype=float32),
#  Array(1.6294948e-07, dtype=float32),
#  Array(1.8062504e-07, dtype=float32),
#  Array(1.9393342e-07, dtype=float32),
#  Array(1.9285005e-07, dtype=float32),
#  Array(1.7618619e-07, dtype=float32),
#  Array(1.8369808e-07, dtype=float32),
#  Array(1.6147361e-07, dtype=float32),
#  Array(1.6354753e-07, dtype=float32),
#  Array(1.6557861e-07, dtype=float32),
#  Array(1.7565098e-07, dtype=float32),
#  Array(1.7481042e-07, dtype=float32),
#  Array(1.647728e-07, dtype=float32),
#  Array(1.4254859e-07, dtype=float32),
#  Array(1.7646687e-07, dtype=float32),
#  Array(1.3726051e-07, dtype=float32),
#  Array(1.7449103e-07, dtype=float32),
#  Array(1.385398e-07, dtype=float32),
#  Array(1.6318393e-07, dtype=float32),
#  Array(1.5189049e-07, dtype=float32),
#  Array(1.5523165e-07, dtype=float32),
#  Array(1.4589634e-07, dtype=float32),
#  Array(1.5184109e-07, dtype=float32),
#  Array(1.2880825e-07, dtype=float32),
#  Array(1.166117e-07, dtype=float32),
#  Array(1.4369795e-07, dtype=float32),
#  Array(1.2483459e-07, dtype=float32),
#  Array(1.489499e-07, dtype=float32),
#  Array(1.3781614e-07, dtype=float32),
#  Array(1.3568078e-07, dtype=float32),
#  Array(1.3764259e-07, dtype=float32),
#  Array(1.3845225e-07, dtype=float32),
#  Array(1.1572754e-07, dtype=float32),
#  Array(1.3535305e-07, dtype=float32),
#  Array(1.2699e-07, dtype=float32),
#  Array(1.2505369e-07, dtype=float32),
#  Array(1.2969066e-07, dtype=float32),
#  Array(1.2304848e-07, dtype=float32),
#  Array(1.0606357e-07, dtype=float32),
#  Array(1.098269e-07, dtype=float32),
#  Array(1.3131218e-07, dtype=float32),
#  Array(1.3308656e-07, dtype=float32),
#  Array(1.218777e-07, dtype=float32),
#  Array(1.3311123e-07, dtype=float32),
#  Array(1.0637295e-07, dtype=float32),
#  Array(1.1973331e-07, dtype=float32),
#  Array(1.1130236e-07, dtype=float32),
#  Array(1.1333946e-07, dtype=float32),
#  Array(1.16991146e-07, dtype=float32),
#  Array(1.2443023e-07, dtype=float32),
#  Array(1.16712656e-07, dtype=float32),
#  Array(1.2065149e-07, dtype=float32),
#  Array(1.1242705e-07, dtype=float32),
#  Array(1.1202851e-07, dtype=float32),
#  Array(1.02605696e-07, dtype=float32),
#  Array(9.4563134e-08, dtype=float32),
#  Array(1.08749326e-07, dtype=float32),
#  Array(9.610021e-08, dtype=float32),
#  Array(1.003129e-07, dtype=float32),
#  Array(1.1867831e-07, dtype=float32),
#  Array(1.0388084e-07, dtype=float32),
#  Array(1.0049456e-07, dtype=float32),
#  Array(1.05017385e-07, dtype=float32),
#  Array(1.05463e-07, dtype=float32),
#  Array(1.1085888e-07, dtype=float32),
#  Array(1.07180995e-07, dtype=float32),
#  Array(9.782759e-08, dtype=float32),
#  Array(9.2720995e-08, dtype=float32),
#  Array(9.533213e-08, dtype=float32),
#  Array(8.608884e-08, dtype=float32),
#  Array(9.4882076e-08, dtype=float32),
#  Array(7.5924106e-08, dtype=float32),
#  Array(1.02112615e-07, dtype=float32),
#  Array(9.354201e-08, dtype=float32),
#  Array(9.777671e-08, dtype=float32),
#  Array(9.833368e-08, dtype=float32),
#  Array(8.729584e-08, dtype=float32),
#  Array(1.02148306e-07, dtype=float32),
#  Array(9.521963e-08, dtype=float32),
#  Array(9.121929e-08, dtype=float32),
#  Array(8.903709e-08, dtype=float32),
#  Array(9.2803774e-08, dtype=float32),
#  Array(8.191881e-08, dtype=float32),
#  Array(9.820282e-08, dtype=float32),
#  Array(9.33891e-08, dtype=float32),
#  Array(8.5327706e-08, dtype=float32),
#  Array(7.9197626e-08, dtype=float32),
#  Array(8.3848576e-08, dtype=float32),
#  Array(8.2744876e-08, dtype=float32),
#  Array(7.558781e-08, dtype=float32),
#  Array(7.322766e-08, dtype=float32),
#  Array(7.3161196e-08, dtype=float32),
#  Array(6.248377e-08, dtype=float32),
#  Array(6.831936e-08, dtype=float32),
#  Array(7.0388296e-08, dtype=float32),
#  Array(7.4987945e-08, dtype=float32),
#  Array(7.403322e-08, dtype=float32),
#  Array(6.369408e-08, dtype=float32),
#  Array(7.217918e-08, dtype=float32),
#  Array(8.5585576e-08, dtype=float32),
#  Array(6.9185376e-08, dtype=float32),
#  Array(7.452462e-08, dtype=float32),
#  Array(8.425796e-08, dtype=float32),
#  Array(7.500601e-08, dtype=float32),
#  Array(7.279106e-08, dtype=float32),
#  Array(7.278979e-08, dtype=float32),
#  Array(6.96382e-08, dtype=float32),
#  Array(6.531413e-08, dtype=float32),
#  Array(6.6846525e-08, dtype=float32),
#  Array(7.975121e-08, dtype=float32),
#  Array(6.3146125e-08, dtype=float32),
#  Array(7.2343795e-08, dtype=float32),
#  Array(6.658188e-08, dtype=float32),
#  Array(6.571302e-08, dtype=float32),
#  Array(6.7704825e-08, dtype=float32),
#  Array(6.897291e-08, dtype=float32),
#  Array(6.3146025e-08, dtype=float32),
#  Array(6.394315e-08, dtype=float32),
#  Array(6.4200925e-08, dtype=float32),
#  Array(6.4849814e-08, dtype=float32),
#  Array(6.8775066e-08, dtype=float32),
#  Array(6.8547806e-08, dtype=float32),
#  Array(5.7793617e-08, dtype=float32),
#  Array(6.740216e-08, dtype=float32),
#  Array(5.232952e-08, dtype=float32),
#  Array(6.461291e-08, dtype=float32),
#  Array(5.382772e-08, dtype=float32),
#  Array(7.823706e-08, dtype=float32),
#  Array(6.1487704e-08, dtype=float32),
#  Array(6.725285e-08, dtype=float32),
#  Array(5.926209e-08, dtype=float32),
#  Array(6.414187e-08, dtype=float32),
#  Array(6.114772e-08, dtype=float32),
#  Array(5.548503e-08, dtype=float32),
#  Array(5.235292e-08, dtype=float32),
#  Array(5.9744785e-08, dtype=float32),
#  Array(5.521589e-08, dtype=float32),
#  Array(5.7250773e-08, dtype=float32),
#  Array(5.7540984e-08, dtype=float32),
#  Array(5.6341033e-08, dtype=float32),
#  Array(5.4699814e-08, dtype=float32),
#  Array(5.775764e-08, dtype=float32),
#  Array(5.0711627e-08, dtype=float32),
#  Array(5.9263474e-08, dtype=float32),
#  Array(5.347704e-08, dtype=float32),
#  Array(4.7669715e-08, dtype=float32),
#  Array(5.704577e-08, dtype=float32),
#  Array(5.0197357e-08, dtype=float32),
#  Array(4.7147374e-08, dtype=float32),
#  Array(4.522662e-08, dtype=float32),
#  Array(5.4250155e-08, dtype=float32),
#  Array(5.0413757e-08, dtype=float32),
#  Array(4.5801002e-08, dtype=float32),
#  Array(5.646732e-08, dtype=float32),
#  Array(5.5722147e-08, dtype=float32),
#  Array(4.511917e-08, dtype=float32),
#  Array(4.5299974e-08, dtype=float32),
#  Array(4.9393474e-08, dtype=float32),
#  Array(5.823445e-08, dtype=float32),
#  Array(4.8758544e-08, dtype=float32),
#  Array(5.297105e-08, dtype=float32),
#  Array(6.016091e-08, dtype=float32),
#  Array(4.5867214e-08, dtype=float32),
#  Array(4.961525e-08, dtype=float32),
#  Array(4.7276675e-08, dtype=float32),
#  Array(5.142053e-08, dtype=float32),
#  Array(4.826013e-08, dtype=float32),
#  Array(5.195286e-08, dtype=float32),
#  Array(4.553342e-08, dtype=float32),
#  Array(3.7979248e-08, dtype=float32),
#  Array(4.4571394e-08, dtype=float32),
#  Array(3.9726235e-08, dtype=float32),
#  Array(4.1145665e-08, dtype=float32),
#  Array(4.8570925e-08, dtype=float32),
#  Array(4.785217e-08, dtype=float32),
#  Array(3.9079822e-08, dtype=float32),
#  Array(3.9671033e-08, dtype=float32),
#  Array(4.637522e-08, dtype=float32),
#  Array(4.410329e-08, dtype=float32),
#  Array(4.572251e-08, dtype=float32),
#  Array(4.1942894e-08, dtype=float32),
#  Array(3.8277353e-08, dtype=float32),
#  Array(3.925352e-08, dtype=float32),
#  Array(4.3723052e-08, dtype=float32),
#  Array(4.0999293e-08, dtype=float32),
#  Array(4.072848e-08, dtype=float32),
#  Array(4.1619202e-08, dtype=float32),
#  Array(4.2684423e-08, dtype=float32),
#  Array(3.6073896e-08, dtype=float32),
#  Array(3.7799705e-08, dtype=float32),
#  Array(4.101489e-08, dtype=float32),
#  Array(4.8758114e-08, dtype=float32),
#  Array(3.989967e-08, dtype=float32),
#  Array(4.249341e-08, dtype=float32),
#  Array(3.767785e-08, dtype=float32),
#  Array(3.962425e-08, dtype=float32),
#  Array(3.957751e-08, dtype=float32),
#  Array(3.8613226e-08, dtype=float32),
#  Array(4.0671477e-08, dtype=float32),
#  Array(3.0267717e-08, dtype=float32),
#  Array(3.704475e-08, dtype=float32),
#  Array(4.314407e-08, dtype=float32),
#  Array(3.3286433e-08, dtype=float32),
#  Array(3.3347245e-08, dtype=float32),
#  Array(3.5365716e-08, dtype=float32),
#  Array(2.8619775e-08, dtype=float32),
#  Array(3.1554112e-08, dtype=float32),
#  Array(3.5849606e-08, dtype=float32),
#  Array(3.6385675e-08, dtype=float32),
#  Array(3.5480824e-08, dtype=float32),
#  Array(2.9003735e-08, dtype=float32),
#  Array(3.4738434e-08, dtype=float32),
#  Array(3.296418e-08, dtype=float32),
#  Array(3.053612e-08, dtype=float32),
#  Array(3.6252683e-08, dtype=float32),
#  Array(3.336416e-08, dtype=float32),
#  Array(3.102386e-08, dtype=float32),
#  Array(2.9962067e-08, dtype=float32),
#  Array(2.9865266e-08, dtype=float32),
#  Array(3.271067e-08, dtype=float32),
#  Array(3.6972096e-08, dtype=float32),
#  Array(3.4842657e-08, dtype=float32),
#  Array(3.6914784e-08, dtype=float32),
#  Array(3.5392254e-08, dtype=float32),
#  Array(3.116444e-08, dtype=float32),
#  Array(3.6490857e-08, dtype=float32),
#  Array(3.211667e-08, dtype=float32),
#  Array(3.3622896e-08, dtype=float32),
#  Array(2.8002386e-08, dtype=float32),
#  Array(3.1125932e-08, dtype=float32),
#  Array(2.670513e-08, dtype=float32),
#  Array(3.0498658e-08, dtype=float32),
#  Array(2.933305e-08, dtype=float32),
#  Array(2.869825e-08, dtype=float32),
#  Array(3.022136e-08, dtype=float32),
#  Array(2.8337496e-08, dtype=float32),
#  Array(2.39661e-08, dtype=float32),
#  Array(3.088581e-08, dtype=float32),
#  Array(2.7494803e-08, dtype=float32),
#  Array(2.5644594e-08, dtype=float32),
#  Array(2.3443167e-08, dtype=float32),
#  Array(3.096728e-08, dtype=float32),
#  Array(2.7205092e-08, dtype=float32),
#  Array(2.4182375e-08, dtype=float32),
#  Array(2.8763074e-08, dtype=float32),
#  Array(2.8537753e-08, dtype=float32),
#  Array(2.7923967e-08, dtype=float32),
#  Array(2.6518887e-08, dtype=float32),
#  Array(2.781463e-08, dtype=float32),
#  Array(2.415104e-08, dtype=float32),
#  Array(2.397151e-08, dtype=float32),
#  Array(2.5212733e-08, dtype=float32),
#  Array(2.409648e-08, dtype=float32),
#  Array(2.4406335e-08, dtype=float32),
#  Array(2.3049733e-08, dtype=float32),
#  Array(2.4922334e-08, dtype=float32),
#  Array(2.5226454e-08, dtype=float32),
#  Array(2.3575469e-08, dtype=float32),
#  Array(2.4550616e-08, dtype=float32),
#  Array(2.4207734e-08, dtype=float32),
#  Array(2.306857e-08, dtype=float32),
#  Array(2.3405319e-08, dtype=float32),
#  Array(2.5834568e-08, dtype=float32),
#  Array(2.2108622e-08, dtype=float32),
#  Array(2.3365589e-08, dtype=float32),
#  Array(2.5468024e-08, dtype=float32),
#  Array(1.9880558e-08, dtype=float32),
#  Array(2.3549958e-08, dtype=float32),
#  Array(2.314513e-08, dtype=float32),
#  Array(2.5781109e-08, dtype=float32),
#  Array(2.4028639e-08, dtype=float32),
#  Array(1.9185736e-08, dtype=float32),
#  Array(2.2981782e-08, dtype=float32),
#  Array(1.9601725e-08, dtype=float32),
#  Array(1.9777493e-08, dtype=float32),
#  Array(2.3306882e-08, dtype=float32),
#  Array(2.0799929e-08, dtype=float32),
#  Array(2.2492978e-08, dtype=float32),
#  Array(2.1028837e-08, dtype=float32),
#  Array(2.2890376e-08, dtype=float32),
#  Array(2.1157092e-08, dtype=float32),
#  Array(2.0658154e-08, dtype=float32),
#  Array(2.0144695e-08, dtype=float32),
#  Array(2.140347e-08, dtype=float32),
#  Array(2.3490422e-08, dtype=float32),
#  Array(2.0866958e-08, dtype=float32),
#  Array(1.7529773e-08, dtype=float32),
#  Array(2.2463851e-08, dtype=float32),
#  Array(2.0164645e-08, dtype=float32),
#  Array(2.091134e-08, dtype=float32),
#  Array(2.1579162e-08, dtype=float32),
#  Array(2.2292278e-08, dtype=float32),
#  Array(2.1011097e-08, dtype=float32),
#  Array(2.3151475e-08, dtype=float32),
#  Array(2.0685935e-08, dtype=float32),
#  Array(2.238416e-08, dtype=float32),
#  Array(2.1937245e-08, dtype=float32),
#  Array(1.8306814e-08, dtype=float32),
#  Array(1.8467336e-08, dtype=float32),
#  Array(1.7986032e-08, dtype=float32),
#  Array(1.614875e-08, dtype=float32),
#  Array(1.8470754e-08, dtype=float32),
#  Array(1.8264322e-08, dtype=float32),
#  Array(1.8351752e-08, dtype=float32),
#  Array(1.7543934e-08, dtype=float32),
#  Array(1.7560275e-08, dtype=float32),
#  Array(1.5702993e-08, dtype=float32),
#  Array(1.8446325e-08, dtype=float32),
#  Array(1.4642006e-08, dtype=float32),
#  Array(1.7844968e-08, dtype=float32),
#  Array(1.9607056e-08, dtype=float32),
#  Array(1.6774706e-08, dtype=float32),
#  Array(1.7972377e-08, dtype=float32),
#  Array(1.616156e-08, dtype=float32),
#  Array(1.9461066e-08, dtype=float32),
#  Array(1.7011068e-08, dtype=float32),
#  Array(1.629625e-08, dtype=float32),
#  Array(1.7188276e-08, dtype=float32),
#  Array(1.4635387e-08, dtype=float32),
#  Array(1.8798227e-08, dtype=float32),
#  Array(1.555097e-08, dtype=float32),
#  Array(1.521898e-08, dtype=float32),
#  Array(1.539911e-08, dtype=float32),
#  Array(1.670895e-08, dtype=float32),
#  Array(1.7647595e-08, dtype=float32),
#  Array(1.4501214e-08, dtype=float32),
#  Array(1.3718536e-08, dtype=float32),
#  Array(1.844517e-08, dtype=float32),
#  Array(1.6196939e-08, dtype=float32),
#  Array(1.472495e-08, dtype=float32),
#  Array(1.3566473e-08, dtype=float32),
#  Array(1.6133248e-08, dtype=float32),
#  Array(1.7150278e-08, dtype=float32),
#  Array(1.6511603e-08, dtype=float32),
#  Array(1.40186485e-08, dtype=float32),
#  Array(1.542153e-08, dtype=float32),
#  Array(1.6441296e-08, dtype=float32),
#  Array(1.7812965e-08, dtype=float32),
#  Array(1.5245393e-08, dtype=float32),
#  Array(1.4658608e-08, dtype=float32),
#  Array(1.33796485e-08, dtype=float32),
#  Array(1.6628896e-08, dtype=float32),
#  Array(1.351017e-08, dtype=float32),
#  Array(1.3712809e-08, dtype=float32),
#  Array(1.2915978e-08, dtype=float32),
#  Array(1.3756393e-08, dtype=float32),
#  Array(1.7176442e-08, dtype=float32),
#  Array(1.2582304e-08, dtype=float32),
#  Array(1.6000184e-08, dtype=float32),
#  Array(1.410559e-08, dtype=float32),
#  Array(1.6994731e-08, dtype=float32),
#  Array(1.6422128e-08, dtype=float32),
#  Array(1.4879041e-08, dtype=float32),
#  Array(1.33927e-08, dtype=float32),
#  Array(1.459338e-08, dtype=float32),
#  Array(1.3628637e-08, dtype=float32),
#  Array(1.4016227e-08, dtype=float32),
#  Array(1.2757479e-08, dtype=float32),
#  Array(1.4139566e-08, dtype=float32),
#  Array(1.418435e-08, dtype=float32),
#  Array(1.3085716e-08, dtype=float32),
#  Array(1.6742176e-08, dtype=float32),
#  Array(1.3222754e-08, dtype=float32),
#  Array(1.2269241e-08, dtype=float32),
#  Array(1.4586911e-08, dtype=float32),
#  Array(1.3214235e-08, dtype=float32),
#  Array(1.4858596e-08, dtype=float32),
#  Array(1.3151891e-08, dtype=float32),
#  Array(1.3561435e-08, dtype=float32),
#  Array(1.1188897e-08, dtype=float32),
#  Array(1.3946961e-08, dtype=float32),
#  Array(1.4694842e-08, dtype=float32),
#  Array(1.1231873e-08, dtype=float32),
#  Array(1.4150632e-08, dtype=float32),
#  Array(1.3400824e-08, dtype=float32),
#  Array(1.2456168e-08, dtype=float32),
#  Array(1.3037687e-08, dtype=float32),
#  Array(1.3505956e-08, dtype=float32),
#  Array(1.3731462e-08, dtype=float32),
#  Array(1.2311766e-08, dtype=float32),
#  Array(1.193477e-08, dtype=float32),
#  Array(1.1650743e-08, dtype=float32),
#  Array(1.4286046e-08, dtype=float32),
#  Array(1.2729078e-08, dtype=float32),
#  Array(1.2554722e-08, dtype=float32),
#  Array(1.3206391e-08, dtype=float32),
#  Array(1.21006645e-08, dtype=float32),
#  Array(1.04576054e-08, dtype=float32),
#  Array(1.10033564e-08, dtype=float32),
#  Array(1.2976313e-08, dtype=float32),
#  Array(1.4223723e-08, dtype=float32),
#  Array(1.2413791e-08, dtype=float32),
#  Array(1.3720097e-08, dtype=float32),
#  Array(1.3088555e-08, dtype=float32),
#  Array(1.09586535e-08, dtype=float32),
#  Array(1.1220445e-08, dtype=float32),
#  Array(1.1594248e-08, dtype=float32),
#  Array(1.2158268e-08, dtype=float32),
#  Array(1.3690939e-08, dtype=float32),
#  Array(1.1872278e-08, dtype=float32),
#  Array(1.29125866e-08, dtype=float32),
#  Array(1.2134811e-08, dtype=float32),
#  Array(1.3130611e-08, dtype=float32),
#  Array(1.2139093e-08, dtype=float32),
#  Array(1.2900346e-08, dtype=float32),
#  Array(1.005372e-08, dtype=float32),
#  Array(1.5299166e-08, dtype=float32),
#  Array(1.1776206e-08, dtype=float32),
#  Array(1.5057266e-08, dtype=float32),
#  Array(1.0369662e-08, dtype=float32),
#  Array(1.2888635e-08, dtype=float32),
#  Array(9.803155e-09, dtype=float32),
#  Array(1.3976207e-08, dtype=float32),
#  Array(1.3283119e-08, dtype=float32),
#  Array(1.2287801e-08, dtype=float32),
#  Array(1.23955886e-08, dtype=float32),
#  Array(1.2334876e-08, dtype=float32),
#  Array(1.0326854e-08, dtype=float32),
#  Array(1.2844808e-08, dtype=float32),
#  Array(1.2134939e-08, dtype=float32),
#  Array(9.415731e-09, dtype=float32),
#  Array(1.1837293e-08, dtype=float32),
#  Array(1.1425465e-08, dtype=float32),
#  Array(1.32360105e-08, dtype=float32),
#  Array(1.0806376e-08, dtype=float32),
#  Array(1.0951786e-08, dtype=float32),
#  Array(1.3136891e-08, dtype=float32),
#  Array(1.241559e-08, dtype=float32),
#  Array(1.2149362e-08, dtype=float32),
#  Array(1.1125236e-08, dtype=float32),
#  Array(1.1133934e-08, dtype=float32),
#  Array(1.1081908e-08, dtype=float32),
#  Array(1.304381e-08, dtype=float32),
#  Array(1.09963665e-08, dtype=float32),
#  Array(1.1176868e-08, dtype=float32),
#  Array(1.1362194e-08, dtype=float32),
#  Array(1.0569613e-08, dtype=float32),
#  Array(1.3775442e-08, dtype=float32),
#  Array(1.1898322e-08, dtype=float32),
#  Array(1.2223362e-08, dtype=float32),
#  Array(1.0296667e-08, dtype=float32),
#  Array(1.0584575e-08, dtype=float32),
#  Array(1.2316804e-08, dtype=float32),
#  Array(1.149069e-08, dtype=float32),
#  Array(1.0826631e-08, dtype=float32),
#  Array(1.0850071e-08, dtype=float32),
#  Array(1.3237149e-08, dtype=float32),
#  Array(1.0040994e-08, dtype=float32),
#  Array(9.268719e-09, dtype=float32),
#  Array(1.0324922e-08, dtype=float32),
#  Array(1.2393644e-08, dtype=float32),
#  Array(1.0012467e-08, dtype=float32),
#  Array(9.52639e-09, dtype=float32),
#  Array(9.851449e-09, dtype=float32),
#  Array(1.0951218e-08, dtype=float32),
#  Array(1.0876352e-08, dtype=float32),
#  Array(1.0065556e-08, dtype=float32),
#  Array(1.1497969e-08, dtype=float32),
#  Array(1.0047227e-08, dtype=float32),
#  Array(1.2398544e-08, dtype=float32),
#  Array(9.447517e-09, dtype=float32),
#  Array(9.898134e-09, dtype=float32),
#  Array(1.2912191e-08, dtype=float32),
#  Array(9.864542e-09, dtype=float32),
#  Array(1.02559605e-08, dtype=float32),
#  Array(9.4833155e-09, dtype=float32),
#  Array(1.1672244e-08, dtype=float32),
#  Array(9.497461e-09, dtype=float32),
#  Array(1.0595703e-08, dtype=float32),
#  Array(8.622851e-09, dtype=float32),
#  Array(1.2212989e-08, dtype=float32),
#  Array(9.35208e-09, dtype=float32),
#  Array(1.0661748e-08, dtype=float32),
#  Array(8.628793e-09, dtype=float32),
#  Array(9.22173e-09, dtype=float32),
#  Array(1.0996575e-08, dtype=float32),
#  Array(9.836987e-09, dtype=float32),
#  Array(9.751125e-09, dtype=float32),
#  Array(1.0113734e-08, dtype=float32),
#  Array(8.5559515e-09, dtype=float32),
#  Array(1.1820542e-08, dtype=float32),
#  Array(9.946405e-09, dtype=float32),
#  Array(1.0475211e-08, dtype=float32),
#  Array(8.441446e-09, dtype=float32),
#  Array(1.1187899e-08, dtype=float32),
#  Array(8.521708e-09, dtype=float32),
#  Array(8.53174e-09, dtype=float32),
#  Array(8.238139e-09, dtype=float32),
#  Array(1.1123097e-08, dtype=float32),
#  Array(1.0342121e-08, dtype=float32),
#  Array(9.926544e-09, dtype=float32),
#  Array(1.0535718e-08, dtype=float32),
#  Array(8.240356e-09, dtype=float32),
#  Array(1.0370863e-08, dtype=float32),
#  Array(1.0237273e-08, dtype=float32),
#  Array(1.0388575e-08, dtype=float32),
#  Array(9.9967075e-09, dtype=float32),
#  Array(9.44828e-09, dtype=float32),
#  Array(1.007751e-08, dtype=float32),
#  Array(9.405934e-09, dtype=float32),
#  Array(7.0207817e-09, dtype=float32),
#  Array(9.798369e-09, dtype=float32),
#  Array(9.138597e-09, dtype=float32),
#  Array(8.419629e-09, dtype=float32),
#  Array(8.603144e-09, dtype=float32),
#  Array(9.616795e-09, dtype=float32),
#  Array(8.306858e-09, dtype=float32),
#  Array(8.584241e-09, dtype=float32),
#  Array(9.155297e-09, dtype=float32),
#  Array(8.271517e-09, dtype=float32),
#  Array(9.5426875e-09, dtype=float32),
#  Array(9.430886e-09, dtype=float32),
#  Array(1.0044785e-08, dtype=float32),
#  Array(8.36473e-09, dtype=float32),
#  Array(9.516963e-09, dtype=float32),
#  Array(7.910374e-09, dtype=float32),
#  Array(8.906189e-09, dtype=float32),
#  Array(9.788349e-09, dtype=float32),
#  Array(8.923895e-09, dtype=float32),
#  Array(8.308354e-09, dtype=float32),
#  Array(8.234117e-09, dtype=float32),
#  Array(9.625478e-09, dtype=float32),
#  Array(8.600084e-09, dtype=float32),
#  Array(9.35022e-09, dtype=float32),
#  Array(9.337104e-09, dtype=float32),
#  Array(9.084339e-09, dtype=float32),
#  Array(8.912283e-09, dtype=float32),
#  Array(8.82189e-09, dtype=float32),
#  Array(7.539594e-09, dtype=float32),
#  Array(1.1096221e-08, dtype=float32),
#  Array(8.065357e-09, dtype=float32),
#  Array(8.0157445e-09, dtype=float32),
#  Array(9.276973e-09, dtype=float32),
#  Array(7.793402e-09, dtype=float32),
#  Array(8.21089e-09, dtype=float32),
#  Array(9.3232355e-09, dtype=float32),
#  Array(9.154394e-09, dtype=float32),
#  Array(6.7683845e-09, dtype=float32),
#  Array(9.936255e-09, dtype=float32),
#  Array(8.486758e-09, dtype=float32),
#  Array(7.3360047e-09, dtype=float32),
#  Array(8.545545e-09, dtype=float32),
#  Array(7.617594e-09, dtype=float32),
#  Array(8.055267e-09, dtype=float32),
#  Array(7.695788e-09, dtype=float32),
#  Array(8.601939e-09, dtype=float32),
#  Array(8.0500575e-09, dtype=float32),
#  Array(6.8835093e-09, dtype=float32),
#  Array(7.0989215e-09, dtype=float32),
#  Array(7.699412e-09, dtype=float32),
#  Array(7.598531e-09, dtype=float32),
#  Array(7.0153856e-09, dtype=float32),
#  Array(8.267418e-09, dtype=float32),
#  Array(7.734914e-09, dtype=float32),
#  Array(7.630225e-09, dtype=float32),
#  Array(7.809878e-09, dtype=float32),
#  Array(8.831657e-09, dtype=float32),
#  Array(7.6721385e-09, dtype=float32),
#  Array(6.9135035e-09, dtype=float32),
#  Array(8.481996e-09, dtype=float32),
#  Array(6.8441044e-09, dtype=float32),
#  Array(8.3972e-09, dtype=float32),
#  Array(7.563946e-09, dtype=float32),
#  Array(7.778052e-09, dtype=float32),
#  Array(6.53039e-09, dtype=float32),
#  Array(8.168639e-09, dtype=float32),
#  Array(7.4498474e-09, dtype=float32),
#  Array(6.9272477e-09, dtype=float32),
#  Array(7.842025e-09, dtype=float32),
#  Array(7.143188e-09, dtype=float32),
#  Array(7.2532305e-09, dtype=float32),
#  Array(6.566842e-09, dtype=float32),
#  Array(7.213131e-09, dtype=float32),
#  Array(6.8471815e-09, dtype=float32),
#  Array(7.84166e-09, dtype=float32),
#  Array(7.733175e-09, dtype=float32),
#  Array(7.847357e-09, dtype=float32),
#  Array(7.149266e-09, dtype=float32),
#  Array(6.2584813e-09, dtype=float32),
#  Array(6.862595e-09, dtype=float32),
#  Array(6.910904e-09, dtype=float32),
#  Array(6.2120273e-09, dtype=float32),
#  Array(7.285323e-09, dtype=float32),
#  Array(8.65644e-09, dtype=float32),
#  Array(7.789316e-09, dtype=float32),
#  Array(8.307326e-09, dtype=float32),
#  Array(7.0583774e-09, dtype=float32),
#  Array(5.914194e-09, dtype=float32),
#  Array(8.3559195e-09, dtype=float32),
#  Array(7.0049984e-09, dtype=float32),
#  Array(6.2983925e-09, dtype=float32),
#  Array(7.456312e-09, dtype=float32),
#  Array(6.4094023e-09, dtype=float32),
#  Array(6.466404e-09, dtype=float32),
#  Array(6.8895063e-09, dtype=float32),
#  Array(5.415811e-09, dtype=float32),
#  Array(6.276132e-09, dtype=float32),
#  Array(6.933764e-09, dtype=float32),
#  Array(7.1998794e-09, dtype=float32),
#  Array(6.0096235e-09, dtype=float32),
#  Array(6.3615584e-09, dtype=float32),
#  Array(6.8175665e-09, dtype=float32),
#  Array(6.380781e-09, dtype=float32),
#  Array(6.267786e-09, dtype=float32),
#  Array(8.792856e-09, dtype=float32),
#  Array(6.1297674e-09, dtype=float32),
#  Array(6.812088e-09, dtype=float32),
#  Array(5.342926e-09, dtype=float32),
#  Array(6.5298105e-09, dtype=float32),
#  Array(6.3783308e-09, dtype=float32),
#  Array(5.372092e-09, dtype=float32),
#  Array(7.870469e-09, dtype=float32),
#  Array(7.238197e-09, dtype=float32),
#  Array(6.900965e-09, dtype=float32),
#  Array(6.656669e-09, dtype=float32),
#  Array(6.663436e-09, dtype=float32),
#  Array(5.1714113e-09, dtype=float32),
#  Array(7.3697244e-09, dtype=float32),
#  Array(7.0196395e-09, dtype=float32),
#  Array(5.580181e-09, dtype=float32),
#  Array(7.22917e-09, dtype=float32),
#  Array(6.7017862e-09, dtype=float32),
#  Array(6.299145e-09, dtype=float32),
#  Array(7.4880715e-09, dtype=float32),
#  Array(6.153631e-09, dtype=float32),
#  Array(7.204982e-09, dtype=float32),
#  Array(5.044785e-09, dtype=float32),
#  Array(6.099593e-09, dtype=float32),
#  Array(6.0478658e-09, dtype=float32),
#  Array(6.8010273e-09, dtype=float32),
#  Array(6.4511494e-09, dtype=float32),
#  Array(7.645427e-09, dtype=float32),
#  Array(6.016861e-09, dtype=float32),
#  Array(6.43846e-09, dtype=float32),
#  Array(6.9185733e-09, dtype=float32),
#  Array(5.7631575e-09, dtype=float32),
#  Array(5.869679e-09, dtype=float32),
#  Array(6.1814194e-09, dtype=float32),
#  Array(6.9401493e-09, dtype=float32),
#  Array(7.0839095e-09, dtype=float32),
#  Array(6.961161e-09, dtype=float32),
#  Array(6.6409065e-09, dtype=float32),
#  Array(6.6660597e-09, dtype=float32),
#  Array(5.533484e-09, dtype=float32),
#  Array(6.386236e-09, dtype=float32),
#  Array(5.692113e-09, dtype=float32),
#  Array(5.1714846e-09, dtype=float32),
#  Array(6.8796173e-09, dtype=float32),
#  Array(5.8426894e-09, dtype=float32),
#  Array(5.777436e-09, dtype=float32),
#  Array(5.6980065e-09, dtype=float32),
#  Array(6.031182e-09, dtype=float32),
#  Array(6.1124297e-09, dtype=float32),
#  Array(6.28948e-09, dtype=float32),
#  Array(5.7129914e-09, dtype=float32),
#  Array(5.9730985e-09, dtype=float32),
#  Array(6.0845156e-09, dtype=float32),
#  Array(5.1792846e-09, dtype=float32),
#  Array(7.3915545e-09, dtype=float32),
#  Array(4.8036735e-09, dtype=float32),
#  Array(7.1909683e-09, dtype=float32),
#  Array(6.1109615e-09, dtype=float32),
#  Array(6.6686674e-09, dtype=float32),
#  Array(5.7770664e-09, dtype=float32),
#  Array(5.1913953e-09, dtype=float32),
#  Array(5.871498e-09, dtype=float32),
#  Array(5.459984e-09, dtype=float32),
#  Array(5.203364e-09, dtype=float32),
#  Array(5.6931033e-09, dtype=float32),
#  Array(5.328216e-09, dtype=float32),
#  Array(5.0391638e-09, dtype=float32),
#  Array(5.7540857e-09, dtype=float32),
#  Array(5.885694e-09, dtype=float32),
#  Array(5.2916254e-09, dtype=float32),
#  Array(5.9583694e-09, dtype=float32),
#  Array(5.6762546e-09, dtype=float32),
#  Array(5.8413914e-09, dtype=float32),
#  Array(6.7843304e-09, dtype=float32),
#  Array(5.5175553e-09, dtype=float32),
#  Array(5.872567e-09, dtype=float32),
#  Array(5.5592015e-09, dtype=float32),
#  Array(5.108246e-09, dtype=float32),
#  Array(5.0551376e-09, dtype=float32),
#  Array(5.8287766e-09, dtype=float32),
#  Array(5.981256e-09, dtype=float32),
#  Array(5.546111e-09, dtype=float32),
#  Array(5.609486e-09, dtype=float32),
#  Array(5.0819535e-09, dtype=float32),
#  Array(5.1314855e-09, dtype=float32),
#  Array(4.9661386e-09, dtype=float32),
#  Array(4.6747277e-09, dtype=float32),
#  Array(5.4328857e-09, dtype=float32),
#  Array(5.546003e-09, dtype=float32)]

# %%
spring_losses.append(loss_list_aa)

# %%
#spring_losses.pop(-1)
#colors = ['#084594', '#dae7f7', '#bcd9ec', '#9ecae1', '#6baed6', '#4292c6']
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b']

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(18, 5))

# Left plot: Loss comparison
for i, beta in enumerate(beta_vals):
    ax1.plot(spring_losses[i], label=f"β value = {beta}", color=colors[-i], linestyle="--")
ax1.plot(spring_losses[-1], label=f"β value = adaptive", color='#FF0000')
ax1.set_yscale("log")
ax1.set_xscale("log")
ax1.set_xlabel("Training iterations")
ax1.set_ylabel("Loss estimate")
ax1.set_title("SPRING Optimizer: Fixed vs Adaptive β")
ax1.legend(loc='lower left')
ax1.grid(True, alpha=0.3)

# Right plot: Beta evolution
ax2.plot(beta_history, color='red', linewidth=2)
ax2.set_xscale("log")
ax2.set_xlabel("Training iterations")
ax2.set_ylabel("β (momentum parameter)")
ax2.set_title("β Evolution in Adaptive SPRING")
ax2.grid(True, alpha=0.3)
ax2.set_ylim([0.6, 1.05])

l = 1-jnp.array(beta_history)
ax3.plot(l, color='red', linewidth=2)
ax3.set_xscale("log")
ax3.set_yscale("log")
ax3.set_xlabel("Training iterations")
ax3.set_ylabel("1 - β ")
ax3.set_title("(1 - β) Evolution in Adaptive SPRING")
ax3.grid(True, alpha=0.3)


plt.tight_layout()
plt.grid(True)
# Optional: plt.savefig("spring_beta_comparison.pdf", bbox_inches="tight")
plt.show()

# %%
#spring_losses.pop(-1)
colors = ['#084594', '#dae7f7', '#bcd9ec', '#9ecae1', '#6baed6', '#4292c6']
#colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b']

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Left plot: Loss comparison
for i, beta in enumerate(beta_vals):
    ax1.plot(spring_losses[i], label=f"β value = {beta}", color=colors[-i], linestyle="--")
ax1.plot(spring_losses[-1], label=f"β value = adaptive", color='tab:orange')
ax1.set_yscale("log")
ax1.set_xscale("log")
ax1.set_xlabel("Training iterations")
ax1.set_ylabel("Loss estimate")
ax1.set_title("SPRING Optimizer: Fixed vs Adaptive β")
ax1.legend(loc='lower left')
ax1.grid(True, alpha=0.3)

# Right plot: Beta evolution
ax2.plot(beta_history, color='tab:orange', linewidth=2)
#ax2.set_yscale("log")
ax2.set_xscale("log")
ax2.set_xlabel("Training iterations")
ax2.set_ylabel("β (momentum parameter)")
ax2.set_title("β Evolution in Adaptive SPRING")
ax2.grid(True, alpha=0.3)
ax2.set_ylim([0.6, 1.05])
# Out:
# (0.6, 1.05)
